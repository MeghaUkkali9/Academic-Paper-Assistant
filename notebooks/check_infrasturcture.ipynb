# %%
import sys
from pathlib import Path

python_version = sys.version_info
print(f"Python Version: {python_version.major}.{python_version.minor}.{python_version.micro}")
print(f"Environment: {sys.executable}")

if python_version >= (3, 12):
    print("✓ Python version compatible")
else:
    print("✗ Need Python 3.12+")
    exit()
# Out:
# Python Version: 3.12.12
# Environment: /Users/meghaukkali/Documents/Academic-Paper-Assistant/.venv/bin/python
# ✓ Python version compatible

# %%
current_dir = Path.cwd()
print(f"Current directory: {current_dir.name}")

# if current_dir.name == "notebook":
#     project_root = current_dir.parent
# elif (current_dir / "compose.yml").exists():
#     project_root = current_dir
# else:
#     project_root = None

# if project_root and (project_root / "compose.yml").exists():
#     print(f"✓ Project root: {project_root}")
# else:
#     print("✗ Missing compose.yml - check directory")
#     exit()
# Out:
# /Users/meghaukkali/Documents/Academic-Paper-Assistant/notebook
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 current_dir = print(Path.cwd())
# ----> 2 print(f"Current directory: {current_dir.name}")
#       3
#       4 # if current_dir.name == "notebook":
#       5 #     project_root = current_dir.parent
#
# AttributeError: 'NoneType' object has no attribute 'name'
