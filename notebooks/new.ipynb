# %%
from pydantic_settings import BaseSettings, SettingsConfigDict

class Test(BaseSettings):
    model_config = SettingsConfigDict(
        env_file=".env",
    )

    jina_api_key: str

print(Test())
# Out:
# jina_api_key='jina_f9fb3f7f731b4ca3b6cf047aca8be2fcF11z9xSFbf0vskACPuT2IHGKtkQu'
